# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temperature.csv')
df
# Out:
#     Day  Temperature
# 0     1           22
# 1     2           24
# 2     3           24
# 3     4           25
# 4     5           23
# 5     6           26
# 6     7           26
# 7     8           25
# 8     9           24
# 9    10           25
# 10   11           26
# 11   12           27
# 12   13           26
# 13   14           25
# 14   15           28

# %%
X = df[['Day']]         
y = df['Temperature']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
# Show coefficients
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)

# Plot
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', label='Predicted')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.title('Linear Regression: Day vs Temperature')
plt.legend()
plt.show()
# Out:
# Slope (Coefficient): 0.25357142857142856
# Intercept: 23.038095238095238
